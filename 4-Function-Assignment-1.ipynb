# %%
#question_1 
#Create a class and function, and list out the items in the list
#Step1 -Logic
list_AI=['Machine Learning',"Neural Networks","Vision","Robotics","Speech Processing","Natural Language Processing"]
print("Sub-fields in AI are:")
for temp in list_AI:
    fun=temp
    print(fun)
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
##question_1 
#Step2-funtion
def Subfields():
    list_AI=["Machine Learning","Neural Networks","Vision","Robotics","Speech Processing","Natural Language Processing"]
    print("Sub-fields in AI are:")
    for item in list_AI:
        print(item)
    return item

# %%
Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# 'Natural Language Processing'

# %%
#question_1 
#step 3 - Class+Function
class SubfieldsAI():
    def Subfields():
        list_AI=["Machine Learning","Neural Networks","Vision","Robotics","Speech Processing","Natural Language Processing"]
        print("Sub-fields in AI are:")
        for item in list_AI:
            print(item)
#        return list_AI

# %%
SubfieldsAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
## Question_2
##Create a function that checks whether the given number is Odd or Even
######Step 1 - logic ##################################
user_in=int(input("Enter the Number:")) 
if user_in % 2==0:
    msg= str(user_in)+" is even number"
    print(msg)
else:
    msg= str(user_in)+" is odd number"
    print(msg)
# Out:
# Enter the Number: 2
# 2 is even number

# %%
## Question_2
# Create a function that checks whether the given number is Odd or Even
####step 2 -Function###############
def OddEven():
    user_in=int(input("Enter the Number:")) 
    if user_in % 2==0:
        msg= str(user_in)+" is even number"
#        print(msg)
    else:
        msg= str(user_in)+" is odd number"
#       print(msg)
    return msg

# %%
OddEven()
# Out:
# Enter the Number: 2
# '2 is even number'

# %%
## Question_2
# Create a function that checks whether the given number is Odd or Even
####Step 3 CLASS##############
class OddEvenM():
    def OddEven():
        user_in=int(input("Enter the Number:")) 
        if user_in % 2==0:
            msg= str(user_in)+" is even number"
#            print(msg)
        else:
            msg= str(user_in)+" is odd number"
#           print(msg)
        return msg

# %%
OddEvenM.OddEven()
# Out:
# Enter the Number: 4
# '4 is even number'

# %%
#Question_3
##Create a function that tells elegibility of marriage for
#male and female according to their age limit like 21 for male and 18 for female
#ElegiblityForMarriage.Elegible()

###Step1-Build logic#######
in_gen=input("Your Gender:")
in_age=int(input("Your age:"))
if in_gen=="male" and in_age<21:
    msg="Not Eligible"
    print(msg)
elif in_gen=="female" and in_age<18:
    msg="Not Eligible"
    print(msg)
else:
    msg="Enter details is incorrect"
    print(msg)
# Out:
# Your Gender: mlae
# Your age: 20
# Enter details is incorrect

# %%
#Question_3
###Step2###############bulid function######
def Elegible():
    in_gen=input("Your Gender:")
    in_age=int(input("Your age:"))
    if in_gen=="male" and in_age<21:
        msg="Not Eligible"
#        print(msg)
    elif in_gen=="female" and in_age<18:
        msg="Not Eligible"
#        print(msg)
    elif (in_gen=="male" and in_age>=21) or (in_gen=="female" and in_age>=18):
        msg="Eligible"
#        print(msg)
    else:
         msg="Enter details Gender or age is incorrect"
#         print(msg)

    return msg

# %%
Elegible()
# Out:
# Your Gender: female
# Your age: 21
# 'Eligible'

# %%
#Question_3
####Step 3 #########addind class#########
class ElegiblityForMarriage:
    def Elegible():
        in_gen=input("Your Gender:")
        in_age=int(input("Your age:"))
        if in_gen=="male" and in_age<21:
            msg="Not Eligible"
 #           print(msg)
        elif in_gen=="female" and in_age<18:
            msg="Not Eligible"
#            print(msg)
        elif (in_gen=="male" and in_age>=21) or (in_gen=="female" and in_age>=18):
            msg="Eligible"
 #           print(msg)
        else:
             msg="Enter details Gender or age is incorrect"
 #            print(msg)

        return msg

# %%
result=ElegiblityForMarriage.Elegible()
print(result)
# Out:
# Your Gender: male
# Your age: 25
# Eligible

# %%
#Question_4
# calculate the percentage of your 10th mark -FindPercent.percentage()
#STEP 1 Build logic
in1=int(input("Subject1:"))
in2=int(input("Subject2:"))
in3=int(input("Subject3:"))
in4=int(input("Subject4:"))
in5=int(input("Subject5:"))
total = in1+in2+in3+in4+in5
print("total:",total)
percentage=(total/500)*100
print("percentage:",percentage)
# Out:
# Subject1: 90
# Subject2: 98
# Subject3: 98
# Subject4: 87
# Subject5: 98
# total: 471
# percentage: 94.19999999999999

# %%
##Question_4
###print area and perimeter of triangle using class and functions
##step2
##build Function###
def percentage():
    in1=int(input("Subject1:"))
    in2=int(input("Subject2:"))
    in3=int(input("Subject3:"))
    in4=int(input("Subject4:"))
    in5=int(input("Subject5:"))
    total = in1+in2+in3+in4+in5
    print("total:",total)
    percentage=(total/500)*100
    print("percentage:",percentage)
    return total,percentage

# %%
percentage()
# Out:
# Subject1: 98
# Subject2: 98
# Subject3: 98
# Subject4: 98
# Subject5: 88
# total: 480
# percentage: 96.0
# (480, 96.0)

# %%
#Question_4
##step3
##Adding Class###
class FindPercent:
    def percentage():
        in1=int(input("Subject1:"))
        in2=int(input("Subject2:"))
        in3=int(input("Subject3:"))
        in4=int(input("Subject4:"))
        in5=int(input("Subject5:"))
        total = in1+in2+in3+in4+in5
        print("total:",total)
        percentage=(total/500)*100
        print("percentage:",percentage)
        msg=f"Total = {total}\n percentage={percentage}"
        return msg

# %%
FindPercent.percentage()
# Out:
# Subject1: 98
# Subject2: 97
# Subject3: 99
# Subject4: 100
# Subject5: 98
# total: 492
# percentage: 98.4
# 'Total = 492\n percentage=98.4'

# %%
#Question_5
#print area and perimeter of triangle using class and functions
#triangle.triangle()
#Height:32
#Breadth:34
#Area formula: (Height*Breadth)/2
#Area of Triangle: 544.0
#Height1:2
#Height2:4
#Breadth:4
#Perimeter formula: Height1+Height2+Breadth
#Perimeter of Triangle: 10

#Step 1 Build logic

h=int(input("Height:"))
b=int(input("Breath:"))
area_tri = (h*b)/2
print("Area of triange:",area_tri)
h1=int(input("Height1:"))
h2=int(input("Height2:"))
b=int(input("breath:"))
peri_tri = h1+h2+b
print("Area of triangle:",peri_tri)
# Out:
# Height: 32
# Breath: 34
# Area of triange: 544.0
# Height1: 2
# Height2: 4
# breath: 4
# Area of triangle: 10

# %%
#Question_5
#Step2#########
def triangle():
    h=int(input("Height:"))
    b=int(input("Breath:"))
    area_tri = (h*b)/2
    print("Area of triange:",area_tri)
    h1=int(input("Height1:"))
    h2=int(input("Height2:"))
    b=int(input("breath:"))
    peri_tri = h1+h2+b
    print("Area of triangle:",peri_tri)
    return (area_tri,peri_tri)

# %%
triangle()
# Out:
# Height: 32
# Breath: 34
# Area of triange: 544.0
# Height1: 2
# Height2: 4
# breath: 4
# Area of triangle: 10
# (544.0, 10)

# %%
#Question_5
##step3
#build class
class triangle:
    def triangle():
        h=int(input("Height:"))
        b=int(input("Breath:"))
        area_tri = (h*b)/2
        print("Area of triange:",area_tri)
        h1=int(input("Height1:"))
        h2=int(input("Height2:"))
        b=int(input("breath:"))
        peri_tri = h1+h2+b
        print("Area of triangle:",peri_tri)
        msg = f"Area of triangle = {area_tri}\nPerimeter of triangle = {peri_tri}"
        return msg

# %%
triangle.triangle()
# Out:
# Height: 32
# Breath: 34
# Area of triange: 544.0
# Height1: 2
# Height2: 4
# breath: 4
# Area of triangle: 10
# 'Area of triangle = 544.0\nPerimeter of triangle = 10'
