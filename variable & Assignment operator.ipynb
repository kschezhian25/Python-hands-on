# %% [markdown]
# num1=10
# num2=30
# add=num1+num2

# %%
print(add)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(add)
#
# NameError: name 'add' is not defined

# %%
print("add)
# Out:
#   Cell In[4], line 1
#     print("add)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("add")
# Out:
# add

# %%
num1=10
num2=20
add=num1+num2
print("add")
print(add)
# Out:
# add
# 30

# %%
First_Name="senthamizh"
second_Name="chezhian"
Name= First_Name+second_Name
print("Name=")
print(Name)
# Out:
# Name=
# senthamizhchezhian

# %%
a=
