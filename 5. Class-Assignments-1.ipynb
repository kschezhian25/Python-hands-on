# %%
##Assignment 5#######################################
from multilogic import multifun
#from filename import classname
multifun.Subfields()
#classname.functionname
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multifun.OddEven()
# Out:
# Enter the Number: 7
# '7 is odd number'

# %%
multifun.Elegible()
# Out:
# Your Gender: male
# Your age: 25
# 'Eligible'

# %%
multifun.percentage()
# Out:
# Subject1: 98
# Subject2: 99
# Subject3: 98
# Subject4: 100
# Subject5: 98
# total: 493
# percentage: 98.6
# 'Total = 493\n percentage=98.6'

# %%
multifun.triangle()
# Out:
# Height: 32
# Breath: 34
# Area of triange: 544.0
# Height1: 2
# Height2: 4
# breath: 2
# Area of triangle: 8
# 'Area of triangle = 544.0\nPerimeter of triangle = 8'
