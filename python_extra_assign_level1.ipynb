# %%
#print
print("Hope AI")

# %%
#buy input
a=input("Enter you institute Name:")
print(a)
# Out:
# Enter you institute Name: Hope AI
# Hope AI

# %%
#Buy inputs
name = input("Enter your name:")
age=input("Enter your age:")
school=input("Enter your school name:")
degree=input("Enter your drgree:")
# Out:
# Enter your name: abc
# Enter your age: 26
# Enter your school name: tg
# Enter your drgree: tt

# %%
#Addition
a=43
b=34
c=a+b
print("add",c)
# Out:
# add 77

# %%
#Subtraction
x=43
y=34
z=a-b
print("sub",z)
# Out:
# sub 9

# %%
#Multiplication
a=63
b=97
c=a*b
print("Mul",c)
# Out:
# Mul 6111

# %%
#Division
a=76
b=31
c=a/b
print("float Div",c)
# Out:
# float Div 2.4516129032258065

# %%
#floor Division
a=76
b=31
c=a//b
print("Floor Div",c)
# Out:
# Floor Div 2

# %%
#Modulo
a=76
b=31
c=a%b
print("Modulo",c)
# Out:
# Modulo 14

# %%
#power
a=4
b=4
c=a**b
print("power",c)
# Out:
# power 256
